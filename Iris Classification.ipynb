# %%
#Import libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import  KNeighborsClassifier
import numpy as np
import matplotlib.pyplot as plt

# %%
#print out the keys in iris dataset
iris =load_iris()
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
# features of iris dataset 
# Sepallength SepalWidth Petalength PetalWidth Species
#print(iris.feature_names)
L1 = iris.feature_names[0]
L2 = iris.feature_names[1]
L3 = iris.feature_names[2]
L4 = iris.feature_names[3]

# %%
# iris['data'] --> check the iris data 
# iris['DESCR'] --> check the iris description

# %%
features= iris.data.T
Sepallength = features[0]
SepalWidth = features[1]
Petalength = features[2]
PetalWidth = features[3]

# %%
#plot each sepal length against sepal width
graph=plt.scatter(Sepallength,SepalWidth,c=iris.target,label=target_names)
plt.xlabel(L1)
plt.ylabel(L2)

plt.legend(*graph.legend_elements(), loc="upper right", title="Classes")
plt.show()

# %%
Xtrain, Xtest,Ytrain,Ytest= train_test_split(iris['data'],iris['target'],random_state=0)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(Xtrain,Ytrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
# testing with a sample
Xnew = np.array([[6.3, 2.5, 5. , 1.9]])
prediction = knn.predict(Xnew)
print(prediction)
# Out:
# [2]

# %%
#Check the accuracy
print(knn.score(Xtest,Ytest))
# Out:
# 0.9736842105263158
